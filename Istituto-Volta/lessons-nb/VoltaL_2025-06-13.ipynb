# %% [markdown]
# # open file

# %% [markdown]
# ## manner 1
#
# 1.   open()
# 2.   .write()
# 3.   .close()
#
#
#
# 1.   open()
# 2.   .read()
# 3.   .close()

# %% [markdown]
# ### Example 1

# %%
path="esempio1.txt"

# %%
f= open(path, 'w')
f.write("Questo è un esempio")
f.close()

# %%
f= open(path, 'r')
data= f.read()
print(data)
# Out:
# Questo è un esempio

# %%
f= ope

# %% [markdown]
# ##
